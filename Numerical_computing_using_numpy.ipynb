# %% [markdown]
# let's create a model which can predict the crop yeild for different region using previous data using numpy arrays.

# %%
import numpy as np

# %%
climate_data = np.array([[73,67,43],
                         [91,88,64],
                         [87,134,58],
                         [102,43,37],
                         [69,96,70]])

# %%
climate_data.shape
# Out:
# (5, 3)

# %%
weights = np.array([0.3,0.2,0.5])

# %%
weights.shape
# Out:
# (3,)

# %%
## 3d array
arr3 = np.array([[[11,12,13],
                 [13,14,15]]
                ,[[15,16,17],
                  [17,18,19]]])

# %%
arr3.shape
# Out:
# (2, 2, 3)

# %%
arr3.dtype
# Out:
# dtype('int64')

# %%
np.matmul(climate_data,weights)
# Out:
# array([56.8, 76.9, 81.9, 57.7, 74.9])

# %%
climate_data @ weights
# Out:
# array([56.8, 76.9, 81.9, 57.7, 74.9])

# %%
## Working with CSV data files
import urllib.request

# %%
## Array indexing and slicing
arr3 = np.array([
    [[11,12,13,14],
     [13,14,15,19]],
    [[15,16,17,21],
     [63,92,36,18]],
    [[98,32,81,23],
     [17,18,19.5,43]],
])

# %%
arr3.shape
# Out:
# (3, 2, 4)

# %%
arr3[1,1,2]
# Out:
# np.float64(36.0)

# %%
## Subarray using ranges
arr3[1:,0:1,:2]
# Out:
# array([[[15., 16.]],
#
#        [[98., 32.]]])
